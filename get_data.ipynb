# %%
print('test')
# Out:
# test

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\whatsapp automate\chat_data.csv")

# %%
df.head()
# Out:
#                           timestamp         phone  role        message
# 0  2026-08-05T09:43:26.993891+00:00  9.173610e+11  user             Hi
# 1  2026-08-05T09:43:36.775044+00:00  9.182194e+11  user  Morning 10 am
# 2  2026-08-05T09:43:47.275677+00:00  9.170098e+11  user   Done already
# 3  2026-08-05T09:44:04.172525+00:00  9.176207e+11  user        Morning
# 4  2026-08-05T09:44:11.325240+00:00  9.182194e+11  user   Evening 6 am

# %%
df['message']
# Out:
# 0                                                Hi
# 1                                     Morning 10 am
# 2                                      Done already
# 3                                           Morning
# 4                                      Evening 6 am
#                            ...
# 3889                                          8 am?
# 3890    So I have to visit somewhere to give exams?
# 3891             Ok mam evening Tak decide karta hu
# 3892                                 Evening 7 to 8
# 3893                                            Yes
# Name: message, Length: 3894, dtype: object

# %%
df['message'].tail(100).to_numpy()
# Out:
# array(['Yes',
#        'Great! 😊  \nHere are the available batch timings:\n\n- Morning: 6:00–7:00 AM, 7:00–8:00 AM, 8:00–9:00 AM, 10:00–11:00 AM  \n- Afternoon: 12:00–1:00 PM  \n- Evening: 4:00–5:00 PM, 5:00–6:00 PM, 6:00–7:00 PM, 7:00–8:00 PM  \n\nWhich timing works best for you?',
#        'Evening 6-7',
#        'Perfect! 😊 The 6:00–7:00 PM evening batch is a wonderful choice.  \n\nSince your timing is now confirmed, the next step is to select your package duration. Would you like to start with a 1-month, 3-month, 6-month, or 1-year package?',
#        'Teacher detail',
#        'Hello! 😊  \nHere are the teachers for the evening batch (6:00–7:00 PM):\n\n- **Priya** — She teaches from 6:00–7:00 PM and is great for beginners and all levels.\n- **Mradula** — Also from 7:00–8:00 AM, but not for the evening batch.\n\nSince you’re interested in the 6:00–7:00 PM slot, you can choose to learn with **Priya**.  \n\nWould you like to proceed with selecting your package duration now?',
# ...

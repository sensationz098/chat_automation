# %%
print('test')
# Out:
# test

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\whatsapp automate\chat_data.csv")

# %%
df.head()
# Out:
#                           timestamp         phone  role        message
# 0  2026-08-05T09:43:26.993891+00:00  9.173610e+11  user             Hi
# 1  2026-08-05T09:43:36.775044+00:00  9.182194e+11  user  Morning 10 am
# 2  2026-08-05T09:43:47.275677+00:00  9.170098e+11  user   Done already
# 3  2026-08-05T09:44:04.172525+00:00  9.176207e+11  user        Morning
# 4  2026-08-05T09:44:11.325240+00:00  9.182194e+11  user   Evening 6 am

# %%
df['message']
# Out:
# 0                                       Hi
# 1                            Morning 10 am
# 2                             Done already
# 3                                  Morning
# 4                             Evening 6 am
#                        ...
# 1268    Kindly elaborate about the session
# 1269                                  Done
# 1270                    Can I get. A trial
# 1271              How can I add my session
# 1272                            Yes please
# Name: message, Length: 1273, dtype: object

# %%
df['message'].head(100).to_numpy()
# Out:
# array(['Hi', 'Morning 10 am', 'Done already', 'Morning', 'Evening 6 am',
#        'For Stress overthinking anxiety', '7 to 8', 'Yes available',
#        'Super i like', 'Disease', 'Ok', 'Ok', 'Wednesday and Friday',
#        'I am malayali is their is any problem',
#        'Hi! Can I get details about the ₹1500 Online Kathak Classes 3-Months offer?',
#        'But I am beginner', 'Yes', "It's not a fraud", 'Mm', 'Okay',
#        "I'm non dancer", 'Yes bye mistake', 'Ok',
#        'Yeah ...plz change my mail id', 'Is this a fraud',
#        'Is this a fraud', 'Okay', 'Please',
#        'Give me all batch timings serially',
#        'Give me all batch timings serially', nan, nan,
#        'Can i have timing please weekends and weekdays batches',
#        'Hello! Can I get more info on Ladies Dance classes ₹600 for 3 months offer?',
#        'Which type dance class',
#        'Rosy Bhardwaj \r\nAge 40\r\nContact no 8219360070\r\nState HP',
#        '8- 9', 'Yes',
# ...
